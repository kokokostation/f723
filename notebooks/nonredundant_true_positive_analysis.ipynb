# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import dill
import re
import networkx as nx
import pandas as pd

from tqdm import tqdm
from itertools import chain
from sklearn.manifold import TSNE
from collections import defaultdict, Counter

from sklearn.model_selection import GroupKFold, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve

from f723.tools.show.classification import plot_precision_recall_curve
from f723.tools.models.application import ClassificationResult
from f723.tools.urs.extraction import assemble_chains
from f723.tools.dataset.entities import make_pair

# %%
NRLIST_PATH = '/home/mikhail/bioinformatics/data/nrlist_3.76_3.0A.csv'
CIF_DIR = '/home/mikhail/bioinformatics/data/NR_3.0/cif/'
OUT_DIR = '/home/mikhail/bioinformatics/data/NR_3.0/out/'
NRLIST_PATH = '/home/mikhail/bioinformatics/data/nrlist_3.76_3.0A.csv'
SEC_STRUCT_DIR = '/home/mikhail/bioinformatics/data/sec_struct'
DATASET_DIR = '/home/mikhail/bioinformatics/data/dataset_all_60'

# %%
def get_batch(index):
    with open(os.path.join(DATASET_DIR, 'batch_{}'.format(index)), 'rb') as infile:
        return dill.load(infile)
    

def get_data():
    return chain.from_iterable((get_batch(i) for i in tqdm(range(30))))

# %%
with open('/home/mikhail/bioinformatics/data/nonredundant.txt', 'r') as infile:
    nonredundant_chain_ids = {tuple(chain_id.split('.cif1_')) for chain_id in infile.read().splitlines()}

# %% [markdown]
# Сначала посмотрим на элементы вторичной структуры, в которых находятся SM-HC-AG пары.
#
# Соберем граф, в котором вершинами будут нуклеотиды, а ребрами -- SM-пары. Тогда, компоненты связности получившегося графа будут элементами вторичной структуры. Есть предположение, что так как SM-HC-AG пары кластеризуются куда лучше других, то им соответствует некоторый очень частотный элемент вторичной структуры, который при этом других неканонических пар не содержит, иначе, вероятно, эти соседствующие пары тоже бы классифицировались хорошо.

# %%
graph = nx.Graph()
noncanonical_pairs = set()
ag_hc_pairs = set()

for pair_data in get_data():
    meta = pair_data.meta
    
    if (meta.pdb_id, meta.pair.nt_left.chain_id) in nonredundant_chain_ids:
        nt_left = meta.pair.nt_left
        nt_right = meta.pair.nt_right
        nt_left_features = pair_data.features.neighbours_left[5]
        nt_right_features = pair_data.features.neighbours_right[5]
        
        node_left = meta.pdb_id, nt_left, nt_left_features.fragment_length, nt_left_features.fragment_index
        node_right = meta.pdb_id, nt_right, nt_right_features.fragment_length, nt_right_features.fragment_index
        
        graph.add_nodes_from([node_left, node_right])

        if pair_data.features.relation == 'SM':
            graph.add_edge(node_left, node_right)
            
            if meta.type == 'noncanonical_bps':
                noncanonical_pairs.add(node_left)
                noncanonical_pairs.add(node_right)
                
                ss = nt_left_features.secondary_structure
                if ss == 'HC' and {nt_left.base, nt_right.base} == {'A', 'G'}:
                    ag_hc_pairs.add(node_left)
                    ag_hc_pairs.add(node_right)
# Out:
# 100%|██████████| 30/30 [01:54<00:00,  3.83s/it]

# %%
components = list(nx.connected_components(graph))

# %%
ag_hc_components = [c for c in components if c & ag_hc_pairs]

# %%
Counter(map(len, ag_hc_components)).most_common()
# Out:
# [(4, 55),
#  (5, 9),
#  (7, 6),
#  (8, 4),
#  (6, 3),
#  (15, 3),
#  (10, 2),
#  (9, 2),
#  (13, 2),
#  (12, 1),
#  (19, 1),
#  (122, 1),
#  (17, 1),
#  (22, 1),
#  (31, 1)]

# %%
for c in ag_hc_components:
    print(len(noncanonical_pairs & c), len(ag_hc_pairs & c))
    print('\n'.join(map(str, c)))
    print()
# Out:
# 2 2
# ('3rw6', Nucleotide(id='H.G.28.', base='G', chain_id='H', index=27), 4, 0)
# ('3rw6', Nucleotide(id='H.A.29.', base='A', chain_id='H', index=28), 4, 1)
# ('3rw6', Nucleotide(id='H.A.31.', base='A', chain_id='H', index=30), 4, 3)
# ('3rw6', Nucleotide(id='H.A.30.', base='A', chain_id='H', index=29), 4, 2)
#
# 2 2
# ('4p95', Nucleotide(id='A.A.570.', base='A', chain_id='A', index=185), 4, 2)
# ('4p95', Nucleotide(id='A.A.571.', base='A', chain_id='A', index=186), 4, 3)
# ('4p95', Nucleotide(id='A.G.568.', base='G', chain_id='A', index=183), 4, 0)
# ('4p95', Nucleotide(id='A.A.569.', base='A', chain_id='A', index=184), 4, 1)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.A.162.', base='A', chain_id='1a', index=155), 4, 3)
# ('4y4o', Nucleotide(id='1a.A.160.', base='A', chain_id='1a', index=153), 4, 1)
# ('4y4o', Nucleotide(id='1a.A.161.', base='A', chain_id='1a', index=154), 4, 2)
# ('4y4o', Nucleotide(id='1a.G.159.', base='G', chain_id='1a', index=152), 4, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.G.299.', base='G', chain_id='1a', index=293), 4, 2)
# ('4y4o', Nucleotide(id='1a.A.298.', base='A', chain_id='1a', index=292), 4, 1)
# ('4y4o', Nucleotide(id='1a.A.300.', base='A', chain_id='1a', index=294), 4, 3)
# ('4y4o', Nucleotide(id='1a.G.297.', base='G', chain_id='1a', index=291), 4, 0)
#
# 7 2
# ('4y4o', Nucleotide(id='1a.C.330.', base='C', chain_id='1a', index=324), 12, 9)
# ('4y4o', Nucleotide(id='1a.A.327.', base='A', chain_id='1a', index=321), 12, 6)
# ('4y4o', Nucleotide(id='1a.G.326.', base='G', chain_id='1a', index=320), 12, 5)
# ('4y4o', Nucleotide(id='1a.C.328.', base='C', chain_id='1a', index=322), 12, 7)
# ('4y4o', Nucleotide(id='1a.A.329.', base='A', chain_id='1a', index=323), 12, 8)
# ('4y4o', Nucleotide(id='1a.G.331.', base='G', chain_id='1a', index=325), 12, 10)
# ('4y4o', Nucleotide(id='1a.C.322.', base='C', chain_id='1a', index=316), 12, 1)
# ('4y4o', Nucleotide(id='1a.A.325.', base='A', chain_id='1a', index=319), 12, 4)
# ('4y4o', Nucleotide(id='1a.U.323.', base='U', chain_id='1a', index=317), 12, 2)
# ('4y4o', Nucleotide(id='1a.A.321.', base='A', chain_id='1a', index=315), 12, 0)
# ('4y4o', Nucleotide(id='1a.G.332.', base='G', chain_id='1a', index=326), 12, 11)
# ('4y4o', Nucleotide(id='1a.G.324.', base='G', chain_id='1a', index=318), 12, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.G.380.', base='G', chain_id='1a', index=374), 4, 0)
# ('4y4o', Nucleotide(id='1a.A.382.', base='A', chain_id='1a', index=376), 4, 2)
# ('4y4o', Nucleotide(id='1a.C.381.', base='C', chain_id='1a', index=375), 4, 1)
# ('4y4o', Nucleotide(id='1a.A.383.', base='A', chain_id='1a', index=377), 4, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.A.461.', base='A', chain_id='1a', index=453), 5, 1)
# ('4y4o', Nucleotide(id='1a.C.470.', base='C', chain_id='1a', index=454), 5, 2)
# ('4y4o', Nucleotide(id='1a.G.471.', base='G', chain_id='1a', index=455), 5, 3)
# ('4y4o', Nucleotide(id='1a.A.472.', base='A', chain_id='1a', index=456), 5, 4)
# ('4y4o', Nucleotide(id='1a.G.460.', base='G', chain_id='1a', index=452), 5, 0)
#
# 4 2
# ('4y4o', Nucleotide(id='1a.G.693.', base='G', chain_id='1a', index=675), 8, 3)
# ('4y4o', Nucleotide(id='1a.G.690.', base='G', chain_id='1a', index=672), 8, 0)
# ('4y4o', Nucleotide(id='1a.U.692.', base='U', chain_id='1a', index=674), 8, 2)
# ('4y4o', Nucleotide(id='1a.U.697.', base='U', chain_id='1a', index=679), 8, 7)
# ('4y4o', Nucleotide(id='1a.A.696.', base='A', chain_id='1a', index=678), 8, 6)
# ('4y4o', Nucleotide(id='1a.A.694.', base='A', chain_id='1a', index=676), 8, 4)
# ('4y4o', Nucleotide(id='1a.G.691.', base='G', chain_id='1a', index=673), 8, 1)
# ('4y4o', Nucleotide(id='1a.A.695.', base='A', chain_id='1a', index=677), 8, 5)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.G.898.', base='G', chain_id='1a', index=874), 4, 0)
# ('4y4o', Nucleotide(id='1a.A.900.', base='A', chain_id='1a', index=876), 4, 2)
# ('4y4o', Nucleotide(id='1a.A.901.', base='A', chain_id='1a', index=877), 4, 3)
# ('4y4o', Nucleotide(id='1a.C.899.', base='C', chain_id='1a', index=875), 4, 1)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.G.1013.', base='G', chain_id='1a', index=990), 4, 0)
# ('4y4o', Nucleotide(id='1a.A.1014.', base='A', chain_id='1a', index=991), 4, 1)
# ('4y4o', Nucleotide(id='1a.A.1016.', base='A', chain_id='1a', index=993), 4, 3)
# ('4y4o', Nucleotide(id='1a.A.1015.', base='A', chain_id='1a', index=992), 4, 2)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.U.1078.', base='U', chain_id='1a', index=1059), 4, 1)
# ('4y4o', Nucleotide(id='1a.G.1077.', base='G', chain_id='1a', index=1058), 4, 0)
# ('4y4o', Nucleotide(id='1a.G.1079.', base='G', chain_id='1a', index=1060), 4, 2)
# ('4y4o', Nucleotide(id='1a.A.1080.', base='A', chain_id='1a', index=1061), 4, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.A.1170.', base='A', chain_id='1a', index=1150), 4, 3)
# ('4y4o', Nucleotide(id='1a.A.1168.', base='A', chain_id='1a', index=1148), 4, 1)
# ('4y4o', Nucleotide(id='1a.A.1169.', base='A', chain_id='1a', index=1149), 4, 2)
# ('4y4o', Nucleotide(id='1a.G.1166.', base='G', chain_id='1a', index=1147), 4, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='1a.G.1266.', base='G', chain_id='1a', index=1246), 4, 0)
# ('4y4o', Nucleotide(id='1a.A.1269.', base='A', chain_id='1a', index=1249), 4, 3)
# ('4y4o', Nucleotide(id='1a.A.1268.', base='A', chain_id='1a', index=1248), 4, 2)
# ('4y4o', Nucleotide(id='1a.C.1267.', base='C', chain_id='1a', index=1247), 4, 1)
#
# 4 2
# ('4y4o', Nucleotide(id='1a.A.1363.A', base='A', chain_id='1a', index=1344), 10, 7)
# ('4y4o', Nucleotide(id='1a.U.1358.', base='U', chain_id='1a', index=1338), 10, 1)
# ('4y4o', Nucleotide(id='1a.G.1361.', base='G', chain_id='1a', index=1341), 10, 4)
# ('4y4o', Nucleotide(id='1a.C.1362.', base='C', chain_id='1a', index=1342), 10, 5)
# ('4y4o', Nucleotide(id='1a.G.1365.', base='G', chain_id='1a', index=1346), 10, 9)
# ('4y4o', Nucleotide(id='1a.C.1359.', base='C', chain_id='1a', index=1339), 10, 2)
# ('4y4o', Nucleotide(id='1a.C.1363.', base='C', chain_id='1a', index=1343), 10, 6)
# ('4y4o', Nucleotide(id='1a.A.1357.', base='A', chain_id='1a', index=1337), 10, 0)
# ('4y4o', Nucleotide(id='1a.U.1364.', base='U', chain_id='1a', index=1345), 10, 8)
# ('4y4o', Nucleotide(id='1a.A.1360.', base='A', chain_id='1a', index=1340), 10, 3)
#
# 13 2
# ('4y4o', Nucleotide(id='2A.U.200.', base='U', chain_id='2A', index=187), 19, 11)
# ('4y4o', Nucleotide(id='2A.A.207.', base='A', chain_id='2A', index=194), 19, 18)
# ('4y4o', Nucleotide(id='2A.C.201.', base='C', chain_id='2A', index=188), 19, 12)
# ('4y4o', Nucleotide(id='2A.A.191.', base='A', chain_id='2A', index=178), 19, 2)
# ('4y4o', Nucleotide(id='2A.A.195.', base='A', chain_id='2A', index=182), 19, 6)
# ('4y4o', Nucleotide(id='2A.U.206.', base='U', chain_id='2A', index=193), 19, 17)
# ('4y4o', Nucleotide(id='2A.G.189.', base='G', chain_id='2A', index=176), 19, 0)
# ('4y4o', Nucleotide(id='2A.U.193.', base='U', chain_id='2A', index=180), 19, 4)
# ('4y4o', Nucleotide(id='2A.A.197.', base='A', chain_id='2A', index=184), 19, 8)
# ('4y4o', Nucleotide(id='2A.A.196.', base='A', chain_id='2A', index=183), 19, 7)
# ('4y4o', Nucleotide(id='2A.G.205.', base='G', chain_id='2A', index=192), 19, 16)
# ('4y4o', Nucleotide(id='2A.G.194.', base='G', chain_id='2A', index=181), 19, 5)
# ('4y4o', Nucleotide(id='2A.A.190.', base='A', chain_id='2A', index=177), 19, 1)
# ('4y4o', Nucleotide(id='2A.A.199.', base='A', chain_id='2A', index=186), 19, 10)
# ('4y4o', Nucleotide(id='2A.A.204.', base='A', chain_id='2A', index=191), 19, 15)
# ('4y4o', Nucleotide(id='2A.C.203.', base='C', chain_id='2A', index=190), 19, 14)
# ('4y4o', Nucleotide(id='2A.C.192.', base='C', chain_id='2A', index=179), 19, 3)
# ('4y4o', Nucleotide(id='2A.C.198.', base='C', chain_id='2A', index=185), 19, 9)
# ('4y4o', Nucleotide(id='2A.U.202.', base='U', chain_id='2A', index=189), 19, 13)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.227.', base='A', chain_id='2A', index=214), 4, 1)
# ('4y4o', Nucleotide(id='2A.A.229.', base='A', chain_id='2A', index=216), 4, 3)
# ('4y4o', Nucleotide(id='2A.A.228.', base='A', chain_id='2A', index=215), 4, 2)
# ('4y4o', Nucleotide(id='2A.G.226.', base='G', chain_id='2A', index=213), 4, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.G.248.', base='G', chain_id='2A', index=235), 5, 1)
# ('4y4o', Nucleotide(id='2A.A.251.', base='A', chain_id='2A', index=238), 5, 4)
# ('4y4o', Nucleotide(id='2A.G.247.', base='G', chain_id='2A', index=234), 5, 0)
# ('4y4o', Nucleotide(id='2A.C.249.', base='C', chain_id='2A', index=236), 5, 2)
# ('4y4o', Nucleotide(id='2A.G.250.', base='G', chain_id='2A', index=237), 5, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.G.465.', base='G', chain_id='2A', index=489), 4, 2)
# ('4y4o', Nucleotide(id='2A.U.464.', base='U', chain_id='2A', index=488), 4, 1)
# ('4y4o', Nucleotide(id='2A.G.463.', base='G', chain_id='2A', index=487), 4, 0)
# ('4y4o', Nucleotide(id='2A.A.466.', base='A', chain_id='2A', index=490), 4, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.G.488.', base='G', chain_id='2A', index=512), 4, 0)
# ('4y4o', Nucleotide(id='2A.G.489.', base='G', chain_id='2A', index=513), 4, 1)
# ('4y4o', Nucleotide(id='2A.A.492.', base='A', chain_id='2A', index=515), 4, 3)
# ('4y4o', Nucleotide(id='2A.G.491.', base='G', chain_id='2A', index=514), 4, 2)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.631.', base='A', chain_id='2A', index=654), 4, 1)
# ('4y4o', Nucleotide(id='2A.A.632.', base='A', chain_id='2A', index=655), 4, 2)
# ('4y4o', Nucleotide(id='2A.G.630.', base='G', chain_id='2A', index=653), 4, 0)
# ('4y4o', Nucleotide(id='2A.A.633.', base='A', chain_id='2A', index=656), 4, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.646.', base='A', chain_id='2A', index=669), 5, 4)
# ('4y4o', Nucleotide(id='2A.C.645.', base='C', chain_id='2A', index=668), 5, 3)
# ('4y4o', Nucleotide(id='2A.A.643.', base='A', chain_id='2A', index=666), 5, 1)
# ('4y4o', Nucleotide(id='2A.A.644.', base='A', chain_id='2A', index=667), 5, 2)
# ('4y4o', Nucleotide(id='2A.G.642.', base='G', chain_id='2A', index=665), 5, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.G.715.', base='G', chain_id='2A', index=760), 6, 2)
# ('4y4o', Nucleotide(id='2A.G.713.', base='G', chain_id='2A', index=758), 6, 0)
# ('4y4o', Nucleotide(id='2A.A.716.', base='A', chain_id='2A', index=761), 6, 3)
# ('4y4o', Nucleotide(id='2A.U.714.', base='U', chain_id='2A', index=759), 6, 1)
# ('4y4o', Nucleotide(id='2A.A.718.', base='A', chain_id='2A', index=763), 6, 5)
# ('4y4o', Nucleotide(id='2A.G.717.', base='G', chain_id='2A', index=762), 6, 4)
#
# 4 4
# ('4y4o', Nucleotide(id='2A.U.747.', base='U', chain_id='2A', index=792), 8, 2)
# ('4y4o', Nucleotide(id='2A.A.752.', base='A', chain_id='2A', index=797), 8, 7)
# ('4y4o', Nucleotide(id='2A.A.751.', base='A', chain_id='2A', index=796), 8, 6)
# ('4y4o', Nucleotide(id='2A.C.749.', base='C', chain_id='2A', index=794), 8, 4)
# ('4y4o', Nucleotide(id='2A.G.745.', base='G', chain_id='2A', index=790), 8, 0)
# ('4y4o', Nucleotide(id='2A.A.746.', base='A', chain_id='2A', index=791), 8, 1)
# ('4y4o', Nucleotide(id='2A.A.750.', base='A', chain_id='2A', index=795), 8, 5)
# ('4y4o', Nucleotide(id='2A.G.748.', base='G', chain_id='2A', index=793), 8, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.783.', base='A', chain_id='2A', index=828), 5, 3)
# ('4y4o', Nucleotide(id='2A.A.784.', base='A', chain_id='2A', index=829), 5, 4)
# ('4y4o', Nucleotide(id='2A.A.782.', base='A', chain_id='2A', index=827), 5, 2)
# ('4y4o', Nucleotide(id='2A.A.781.', base='A', chain_id='2A', index=826), 5, 1)
# ('4y4o', Nucleotide(id='2A.G.780.', base='G', chain_id='2A', index=825), 5, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.C.961.', base='C', chain_id='2A', index=1004), 6, 5)
# ('4y4o', Nucleotide(id='2A.A.957.', base='A', chain_id='2A', index=1000), 6, 1)
# ('4y4o', Nucleotide(id='2A.A.960.', base='A', chain_id='2A', index=1003), 6, 4)
# ('4y4o', Nucleotide(id='2A.A.959.', base='A', chain_id='2A', index=1002), 6, 3)
# ('4y4o', Nucleotide(id='2A.U.958.', base='U', chain_id='2A', index=1001), 6, 2)
# ('4y4o', Nucleotide(id='2A.G.956.', base='G', chain_id='2A', index=999), 6, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.1226.', base='A', chain_id='2A', index=1270), 4, 3)
# ('4y4o', Nucleotide(id='2A.G.1223.', base='G', chain_id='2A', index=1267), 4, 0)
# ('4y4o', Nucleotide(id='2A.G.1225.', base='G', chain_id='2A', index=1269), 4, 2)
# ('4y4o', Nucleotide(id='2A.C.1224.', base='C', chain_id='2A', index=1268), 4, 1)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.1366.', base='A', chain_id='2A', index=1410), 4, 2)
# ('4y4o', Nucleotide(id='2A.G.1364.', base='G', chain_id='2A', index=1408), 4, 0)
# ('4y4o', Nucleotide(id='2A.A.1367.', base='A', chain_id='2A', index=1411), 4, 3)
# ('4y4o', Nucleotide(id='2A.A.1365.', base='A', chain_id='2A', index=1409), 4, 1)
#
# 12 4
# ('4y4o', Nucleotide(id='2A.C.1691.', base='C', chain_id='2A', index=1736), 15, 4)
# ('4y4o', Nucleotide(id='2A.A.1690.', base='A', chain_id='2A', index=1735), 15, 3)
# ('4y4o', Nucleotide(id='2A.A.1698.', base='A', chain_id='2A', index=1743), 15, 11)
# ('4y4o', Nucleotide(id='2A.G.1699.', base='G', chain_id='2A', index=1744), 15, 12)
# ('4y4o', Nucleotide(id='2A.U.1692.', base='U', chain_id='2A', index=1737), 15, 5)
# ('4y4o', Nucleotide(id='2A.U.1693.', base='U', chain_id='2A', index=1738), 15, 6)
# ('4y4o', Nucleotide(id='2A.U.1688.', base='U', chain_id='2A', index=1733), 15, 1)
# ('4y4o', Nucleotide(id='2A.C.1694.', base='C', chain_id='2A', index=1739), 15, 7)
# ('4y4o', Nucleotide(id='2A.G.1697.', base='G', chain_id='2A', index=1742), 15, 10)
# ('4y4o', Nucleotide(id='2A.A.1689.', base='A', chain_id='2A', index=1734), 15, 2)
# ('4y4o', Nucleotide(id='2A.G.1695.', base='G', chain_id='2A', index=1740), 15, 8)
# ('4y4o', Nucleotide(id='2A.G.1687.', base='G', chain_id='2A', index=1732), 15, 0)
# ('4y4o', Nucleotide(id='2A.G.1696.', base='G', chain_id='2A', index=1741), 15, 9)
# ('4y4o', Nucleotide(id='2A.A.1701.', base='A', chain_id='2A', index=1746), 15, 14)
# ('4y4o', Nucleotide(id='2A.A.1700.', base='A', chain_id='2A', index=1745), 15, 13)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.1809.', base='A', chain_id='2A', index=1838), 4, 2)
# ('4y4o', Nucleotide(id='2A.U.1808.', base='U', chain_id='2A', index=1837), 4, 1)
# ('4y4o', Nucleotide(id='2A.G.1807.', base='G', chain_id='2A', index=1836), 4, 0)
# ('4y4o', Nucleotide(id='2A.A.1810.', base='A', chain_id='2A', index=1839), 4, 3)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.1877.', base='A', chain_id='2A', index=1897), 4, 3)
# ('4y4o', Nucleotide(id='2A.G.1865.', base='G', chain_id='2A', index=1894), 4, 0)
# ('4y4o', Nucleotide(id='2A.A.1876.', base='A', chain_id='2A', index=1896), 4, 2)
# ('4y4o', Nucleotide(id='2A.C.1866.', base='C', chain_id='2A', index=1895), 4, 1)
#
# 4 2
# ('4y4o', Nucleotide(id='2A.A.2309.', base='A', chain_id='2A', index=2319), 9, 5)
# ('4y4o', Nucleotide(id='2A.G.2304.', base='G', chain_id='2A', index=2314), 9, 0)
# ('4y4o', Nucleotide(id='2A.C.2306.', base='C', chain_id='2A', index=2316), 9, 2)
# ('4y4o', Nucleotide(id='2A.U.2312.', base='U', chain_id='2A', index=2322), 9, 8)
# ('4y4o', Nucleotide(id='2A.G.2308.', base='G', chain_id='2A', index=2318), 9, 4)
# ('4y4o', Nucleotide(id='2A.A.2305.', base='A', chain_id='2A', index=2315), 9, 1)
# ('4y4o', Nucleotide(id='2A.A.2311.', base='A', chain_id='2A', index=2321), 9, 7)
# ('4y4o', Nucleotide(id='2A.G.2307.', base='G', chain_id='2A', index=2317), 9, 3)
# ('4y4o', Nucleotide(id='2A.A.2310.', base='A', chain_id='2A', index=2320), 9, 6)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.2376.', base='A', chain_id='2A', index=2386), 4, 1)
# ('4y4o', Nucleotide(id='2A.A.2378.', base='A', chain_id='2A', index=2388), 4, 3)
# ('4y4o', Nucleotide(id='2A.A.2377.', base='A', chain_id='2A', index=2387), 4, 2)
# ('4y4o', Nucleotide(id='2A.G.2375.', base='G', chain_id='2A', index=2385), 4, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.C.2477.', base='C', chain_id='2A', index=2487), 7, 5)
# ('4y4o', Nucleotide(id='2A.G.2472.', base='G', chain_id='2A', index=2482), 7, 0)
# ('4y4o', Nucleotide(id='2A.U.2473.', base='U', chain_id='2A', index=2483), 7, 1)
# ('4y4o', Nucleotide(id='2A.A.2476.', base='A', chain_id='2A', index=2486), 7, 4)
# ('4y4o', Nucleotide(id='2A.A.2478.', base='A', chain_id='2A', index=2488), 7, 6)
# ('4y4o', Nucleotide(id='2A.C.2475.', base='C', chain_id='2A', index=2485), 7, 3)
# ('4y4o', Nucleotide(id='2A.C.2474.', base='C', chain_id='2A', index=2484), 7, 2)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.A.2598.', base='A', chain_id='2A', index=2608), 4, 3)
# ('4y4o', Nucleotide(id='2A.G.2595.', base='G', chain_id='2A', index=2605), 4, 0)
# ('4y4o', Nucleotide(id='2A.G.2597.', base='G', chain_id='2A', index=2607), 4, 2)
# ('4y4o', Nucleotide(id='2A.U.2596.', base='U', chain_id='2A', index=2606), 4, 1)
#
# 11 4
# ('4y4o', Nucleotide(id='2A.C.2658.', base='C', chain_id='2A', index=2668), 15, 5)
# ('4y4o', Nucleotide(id='2A.G.2664.', base='G', chain_id='2A', index=2674), 15, 11)
# ('4y4o', Nucleotide(id='2A.G.2663.', base='G', chain_id='2A', index=2673), 15, 10)
# ('4y4o', Nucleotide(id='2A.U.2656.', base='U', chain_id='2A', index=2666), 15, 3)
# ('4y4o', Nucleotide(id='2A.G.2655.', base='G', chain_id='2A', index=2665), 15, 2)
# ('4y4o', Nucleotide(id='2A.U.2653.', base='U', chain_id='2A', index=2663), 15, 0)
# ('4y4o', Nucleotide(id='2A.A.2657.', base='A', chain_id='2A', index=2667), 15, 4)
# ('4y4o', Nucleotide(id='2A.G.2659.', base='G', chain_id='2A', index=2669), 15, 6)
# ('4y4o', Nucleotide(id='2A.A.2665.', base='A', chain_id='2A', index=2675), 15, 12)
# ('4y4o', Nucleotide(id='2A.C.2667.', base='C', chain_id='2A', index=2677), 15, 14)
# ('4y4o', Nucleotide(id='2A.A.2660.', base='A', chain_id='2A', index=2670), 15, 7)
# ('4y4o', Nucleotide(id='2A.G.2661.', base='G', chain_id='2A', index=2671), 15, 8)
# ('4y4o', Nucleotide(id='2A.A.2654.', base='A', chain_id='2A', index=2664), 15, 1)
# ('4y4o', Nucleotide(id='2A.C.2666.', base='C', chain_id='2A', index=2676), 15, 13)
# ('4y4o', Nucleotide(id='2A.A.2662.', base='A', chain_id='2A', index=2672), 15, 9)
#
# 11 2
# ('4y4o', Nucleotide(id='2A.A.2758.', base='A', chain_id='2A', index=2769), 13, 12)
# ('4y4o', Nucleotide(id='2A.U.2754.', base='U', chain_id='2A', index=2765), 13, 8)
# ('4y4o', Nucleotide(id='2A.A.2753.', base='A', chain_id='2A', index=2764), 13, 7)
# ('4y4o', Nucleotide(id='2A.A.2749.', base='A', chain_id='2A', index=2760), 13, 3)
# ('4y4o', Nucleotide(id='2A.G.2751.', base='G', chain_id='2A', index=2762), 13, 5)
# ('4y4o', Nucleotide(id='2A.A.2750.', base='A', chain_id='2A', index=2761), 13, 4)
# ('4y4o', Nucleotide(id='2A.C.2752.', base='C', chain_id='2A', index=2763), 13, 6)
# ('4y4o', Nucleotide(id='2A.G.2747.', base='G', chain_id='2A', index=2758), 13, 1)
# ('4y4o', Nucleotide(id='2A.C.2755.', base='C', chain_id='2A', index=2766), 13, 9)
# ('4y4o', Nucleotide(id='2A.U.2756.', base='U', chain_id='2A', index=2767), 13, 10)
# ('4y4o', Nucleotide(id='2A.A.2757.', base='A', chain_id='2A', index=2768), 13, 11)
# ('4y4o', Nucleotide(id='2A.A.2748.', base='A', chain_id='2A', index=2759), 13, 2)
# ('4y4o', Nucleotide(id='2A.U.2746.', base='U', chain_id='2A', index=2757), 13, 0)
#
# 2 2
# ('4y4o', Nucleotide(id='2A.C.2858.', base='C', chain_id='2A', index=2866), 4, 1)
# ('4y4o', Nucleotide(id='2A.G.2859.', base='G', chain_id='2A', index=2867), 4, 2)
# ('4y4o', Nucleotide(id='2A.A.2860.', base='A', chain_id='2A', index=2868), 4, 3)
# ('4y4o', Nucleotide(id='2A.G.2857.', base='G', chain_id='2A', index=2865), 4, 0)
#
# 2 2
# ('4far', Nucleotide(id='A.G.90.', base='G', chain_id='A', index=89), 4, 0)
# ('4far', Nucleotide(id='A.C.91.', base='C', chain_id='A', index=90), 4, 1)
# ('4far', Nucleotide(id='A.A.93.', base='A', chain_id='A', index=92), 4, 3)
# ('4far', Nucleotide(id='A.G.92.', base='G', chain_id='A', index=91), 4, 2)
#
# 2 2
# ('4far', Nucleotide(id='A.A.277.', base='A', chain_id='A', index=276), 4, 2)
# ('4far', Nucleotide(id='A.A.276.', base='A', chain_id='A', index=275), 4, 1)
# ('4far', Nucleotide(id='A.A.278.', base='A', chain_id='A', index=277), 4, 3)
# ('4far', Nucleotide(id='A.G.275.', base='G', chain_id='A', index=274), 4, 0)
#
# 2 2
# ('2r8s', Nucleotide(id='R.A.152.', base='A', chain_id='R', index=50), 4, 2)
# ('2r8s', Nucleotide(id='R.A.151.', base='A', chain_id='R', index=49), 4, 1)
# ('2r8s', Nucleotide(id='R.G.150.', base='G', chain_id='R', index=48), 4, 0)
# ('2r8s', Nucleotide(id='R.A.153.', base='A', chain_id='R', index=51), 4, 3)
#
# 2 2
# ('4qlm', Nucleotide(id='A.A.56.', base='A', chain_id='A', index=55), 4, 1)
# ('4qlm', Nucleotide(id='A.G.55.', base='G', chain_id='A', index=54), 4, 0)
# ('4qlm', Nucleotide(id='A.A.57.', base='A', chain_id='A', index=56), 4, 2)
# ('4qlm', Nucleotide(id='A.A.58.', base='A', chain_id='A', index=57), 4, 3)
#
# 2 2
# ('4wfl', Nucleotide(id='A.A.85.', base='A', chain_id='A', index=82), 4, 3)
# ('4wfl', Nucleotide(id='A.A.84.', base='A', chain_id='A', index=81), 4, 2)
# ('4wfl', Nucleotide(id='A.U.83.', base='U', chain_id='A', index=80), 4, 1)
# ('4wfl', Nucleotide(id='A.G.82.', base='G', chain_id='A', index=79), 4, 0)
#
# 2 2
# ('5fjc', Nucleotide(id='A.A.52.', base='A', chain_id='A', index=51), 4, 2)
# ('5fjc', Nucleotide(id='A.G.50.', base='G', chain_id='A', index=49), 4, 0)
# ('5fjc', Nucleotide(id='A.A.51.', base='A', chain_id='A', index=50), 4, 1)
# ('5fjc', Nucleotide(id='A.A.53.', base='A', chain_id='A', index=52), 4, 3)
#
# 2 2
# ('5fjc', Nucleotide(id='A.G.74.', base='G', chain_id='A', index=73), 4, 0)
# ('5fjc', Nucleotide(id='A.A.76.', base='A', chain_id='A', index=75), 4, 2)
# ('5fjc', Nucleotide(id='A.A.77.', base='A', chain_id='A', index=76), 4, 3)
# ('5fjc', Nucleotide(id='A.A.75.', base='A', chain_id='A', index=74), 4, 1)
#
# 2 2
# ('1u9s', Nucleotide(id='A.U.101.', base='U', chain_id='A', index=26), 4, 1)
# ('1u9s', Nucleotide(id='A.G.100.', base='G', chain_id='A', index=25), 4, 0)
# ('1u9s', Nucleotide(id='A.A.103.', base='A', chain_id='A', index=28), 4, 3)
# ('1u9s', Nucleotide(id='A.A.102.', base='A', chain_id='A', index=27), 4, 2)
#
# 2 2
# ('1u9s', Nucleotide(id='A.A.185.', base='A', chain_id='A', index=110), 7, 3)
# ('1u9s', Nucleotide(id='A.U.183.', base='U', chain_id='A', index=108), 7, 1)
# ('1u9s', Nucleotide(id='A.A.187.', base='A', chain_id='A', index=112), 7, 5)
# ('1u9s', Nucleotide(id='A.A.184.', base='A', chain_id='A', index=109), 7, 2)
# ('1u9s', Nucleotide(id='A.G.186.', base='G', chain_id='A', index=111), 7, 4)
# ('1u9s', Nucleotide(id='A.G.182.', base='G', chain_id='A', index=107), 7, 0)
# ('1u9s', Nucleotide(id='A.G.188.', base='G', chain_id='A', index=113), 7, 6)
#
# 2 2
# ('1u9s', Nucleotide(id='A.G.205.', base='G', chain_id='A', index=130), 4, 0)
# ('1u9s', Nucleotide(id='A.C.206.', base='C', chain_id='A', index=131), 4, 1)
# ('1u9s', Nucleotide(id='A.A.208.', base='A', chain_id='A', index=133), 4, 3)
# ('1u9s', Nucleotide(id='A.A.207.', base='A', chain_id='A', index=132), 4, 2)
#
# 2 2
# ('1kh6', Nucleotide(id='A.G.29.', base='G', chain_id='A', index=28), 4, 0)
# ('1kh6', Nucleotide(id='A.A.30.', base='A', chain_id='A', index=29), 4, 1)
# ('1kh6', Nucleotide(id='A.A.32.', base='A', chain_id='A', index=31), 4, 3)
# ('1kh6', Nucleotide(id='A.A.31.', base='A', chain_id='A', index=30), 4, 2)
#
# 2 2
# ('1f1t', Nucleotide(id='A.A.18.', base='A', chain_id='A', index=17), 4, 3)
# ('1f1t', Nucleotide(id='A.G.17.', base='G', chain_id='A', index=16), 4, 2)
# ('1f1t', Nucleotide(id='A.A.16.', base='A', chain_id='A', index=15), 4, 1)
# ('1f1t', Nucleotide(id='A.G.15.', base='G', chain_id='A', index=14), 4, 0)
#
# 2 2
# ('4yaz', Nucleotide(id='R.G.28.', base='G', chain_id='R', index=27), 4, 2)
# ('4yaz', Nucleotide(id='R.G.26.', base='G', chain_id='R', index=25), 4, 0)
# ('4yaz', Nucleotide(id='R.C.27.', base='C', chain_id='R', index=26), 4, 1)
# ('4yaz', Nucleotide(id='R.A.29.', base='A', chain_id='R', index=28), 4, 3)
#
# 2 2
# ('4jf2', Nucleotide(id='A.A.12.', base='A', chain_id='A', index=11), 4, 3)
# ('4jf2', Nucleotide(id='A.G.9.', base='G', chain_id='A', index=8), 4, 0)
# ('4jf2', Nucleotide(id='A.A.10.', base='A', chain_id='A', index=9), 4, 1)
# ('4jf2', Nucleotide(id='A.A.11.', base='A', chain_id='A', index=10), 4, 2)
#
# 3 2
# ('6dtd', Nucleotide(id='C.A.23.', base='A', chain_id='C', index=22), 8, 7)
# ('6dtd', Nucleotide(id='C.U.18.', base='U', chain_id='C', index=17), 8, 2)
# ('6dtd', Nucleotide(id='C.U.21.', base='U', chain_id='C', index=20), 8, 5)
# ('6dtd', Nucleotide(id='C.U.19.', base='U', chain_id='C', index=18), 8, 3)
# ('6dtd', Nucleotide(id='C.C.16.', base='C', chain_id='C', index=15), 8, 0)
# ('6dtd', Nucleotide(id='C.U.20.', base='U', chain_id='C', index=19), 8, 4)
# ('6dtd', Nucleotide(id='C.U.17.', base='U', chain_id='C', index=16), 8, 1)
# ('6dtd', Nucleotide(id='C.G.22.', base='G', chain_id='C', index=21), 8, 6)
#
# 2 2
# ('5x2g', Nucleotide(id='B.A.36.', base='A', chain_id='B', index=35), 4, 3)
# ('5x2g', Nucleotide(id='B.A.34.', base='A', chain_id='B', index=33), 4, 1)
# ('5x2g', Nucleotide(id='B.G.33.', base='G', chain_id='B', index=32), 4, 0)
# ('5x2g', Nucleotide(id='B.A.35.', base='A', chain_id='B', index=34), 4, 2)
#
# 2 2
# ('3pdr', Nucleotide(id='X.G.100.', base='G', chain_id='X', index=85), 7, 0)
# ('3pdr', Nucleotide(id='X.U.104.', base='U', chain_id='X', index=89), 7, 4)
# ('3pdr', Nucleotide(id='X.C.102.', base='C', chain_id='X', index=87), 7, 2)
# ('3pdr', Nucleotide(id='X.A.106.', base='A', chain_id='X', index=91), 7, 6)
# ('3pdr', Nucleotide(id='X.A.101.', base='A', chain_id='X', index=86), 7, 1)
# ('3pdr', Nucleotide(id='X.A.103.', base='A', chain_id='X', index=88), 7, 3)
# ('3pdr', Nucleotide(id='X.A.105.', base='A', chain_id='X', index=90), 7, 5)
#
# 2 2
# ('1l9a', Nucleotide(id='B.A.201.', base='A', chain_id='B', index=89), 4, 3)
# ('1l9a', Nucleotide(id='B.G.198.', base='G', chain_id='B', index=86), 4, 0)
# ('1l9a', Nucleotide(id='B.A.199.', base='A', chain_id='B', index=87), 4, 1)
# ('1l9a', Nucleotide(id='B.A.200.', base='A', chain_id='B', index=88), 4, 2)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.G.91.', base='G', chain_id='L5', index=90), 5, 1)
# ('6qzp', Nucleotide(id='L5.C.92.', base='C', chain_id='L5', index=91), 5, 2)
# ('6qzp', Nucleotide(id='L5.A.94.', base='A', chain_id='L5', index=93), 5, 4)
# ('6qzp', Nucleotide(id='L5.G.93.', base='G', chain_id='L5', index=92), 5, 3)
# ('6qzp', Nucleotide(id='L5.G.90.', base='G', chain_id='L5', index=89), 5, 0)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.U.370.', base='U', chain_id='L5', index=369), 4, 1)
# ('6qzp', Nucleotide(id='L5.A.372.', base='A', chain_id='L5', index=371), 4, 3)
# ('6qzp', Nucleotide(id='L5.G.369.', base='G', chain_id='L5', index=368), 4, 0)
# ('6qzp', Nucleotide(id='L5.A.371.', base='A', chain_id='L5', index=370), 4, 2)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.A.1254.', base='A', chain_id='L5', index=850), 5, 1)
# ('6qzp', Nucleotide(id='L5.G.1253.', base='G', chain_id='L5', index=849), 5, 0)
# ('6qzp', Nucleotide(id='L5.A.1257.', base='A', chain_id='L5', index=853), 5, 4)
# ('6qzp', Nucleotide(id='L5.A.1255.', base='A', chain_id='L5', index=851), 5, 2)
# ('6qzp', Nucleotide(id='L5.G.1256.', base='G', chain_id='L5', index=852), 5, 3)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.G.1562.', base='G', chain_id='L5', index=1158), 4, 0)
# ('6qzp', Nucleotide(id='L5.A.1564.', base='A', chain_id='L5', index=1160), 4, 2)
# ('6qzp', Nucleotide(id='L5.A.1563.', base='A', chain_id='L5', index=1159), 4, 1)
# ('6qzp', Nucleotide(id='L5.A.1565.', base='A', chain_id='L5', index=1161), 4, 3)
#
# 4 2
# ('6qzp', Nucleotide(id='L5.C.1628.', base='C', chain_id='L5', index=1224), 7, 0)
# ('6qzp', Nucleotide(id='L5.A.1632.', base='A', chain_id='L5', index=1228), 7, 4)
# ('6qzp', Nucleotide(id='L5.G.1629.', base='G', chain_id='L5', index=1225), 7, 1)
# ('6qzp', Nucleotide(id='L5.A.1634.', base='A', chain_id='L5', index=1230), 7, 6)
# ('6qzp', Nucleotide(id='L5.G.1633.', base='G', chain_id='L5', index=1229), 7, 5)
# ('6qzp', Nucleotide(id='L5.A.1630.', base='A', chain_id='L5', index=1226), 7, 2)
# ('6qzp', Nucleotide(id='L5.A.1631.', base='A', chain_id='L5', index=1227), 7, 3)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.G.1865.', base='G', chain_id='L5', index=1457), 5, 0)
# ('6qzp', Nucleotide(id='L5.A.1867.', base='A', chain_id='L5', index=1459), 5, 2)
# ('6qzp', Nucleotide(id='L5.A.1868.', base='A', chain_id='L5', index=1460), 5, 3)
# ('6qzp', Nucleotide(id='L5.UR3.1866.', base='UR3', chain_id='L5', index=1458), 5, 1)
# ('6qzp', Nucleotide(id='L5.G.1869.', base='G', chain_id='L5', index=1461), 5, 4)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.U.2580.', base='U', chain_id='L5', index=2037), 4, 1)
# ('6qzp', Nucleotide(id='L5.A.2581.', base='A', chain_id='L5', index=2038), 4, 2)
# ('6qzp', Nucleotide(id='L5.A.2582.', base='A', chain_id='L5', index=2039), 4, 3)
# ('6qzp', Nucleotide(id='L5.G.2579.', base='G', chain_id='L5', index=2036), 4, 0)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.A.2812.', base='A', chain_id='L5', index=2269), 5, 1)
# ('6qzp', Nucleotide(id='L5.A.2815.', base='A', chain_id='L5', index=2272), 5, 4)
# ('6qzp', Nucleotide(id='L5.A.2813.', base='A', chain_id='L5', index=2270), 5, 2)
# ('6qzp', Nucleotide(id='L5.G.2811.', base='G', chain_id='L5', index=2268), 5, 0)
# ('6qzp', Nucleotide(id='L5.C.2814.', base='C', chain_id='L5', index=2271), 5, 3)
#
# 12 4
# ('6qzp', Nucleotide(id='L5.U.2880.', base='U', chain_id='L5', index=2337), 15, 12)
# ('6qzp', Nucleotide(id='L5.A.2881.', base='A', chain_id='L5', index=2338), 15, 13)
# ('6qzp', Nucleotide(id='L5.G.2878.', base='G', chain_id='L5', index=2335), 15, 10)
# ('6qzp', Nucleotide(id='L5.G.2877.', base='G', chain_id='L5', index=2334), 15, 9)
# ('6qzp', Nucleotide(id='L5.C.2872.', base='C', chain_id='L5', index=2329), 15, 4)
# ('6qzp', Nucleotide(id='L5.U.2869.', base='U', chain_id='L5', index=2326), 15, 1)
# ('6qzp', Nucleotide(id='L5.U.2873.', base='U', chain_id='L5', index=2330), 15, 5)
# ('6qzp', Nucleotide(id='L5.G.2876.', base='G', chain_id='L5', index=2333), 15, 8)
# ('6qzp', Nucleotide(id='L5.A.2871.', base='A', chain_id='L5', index=2328), 15, 3)
# ('6qzp', Nucleotide(id='L5.A.2870.', base='A', chain_id='L5', index=2327), 15, 2)
# ('6qzp', Nucleotide(id='L5.C.2875.', base='C', chain_id='L5', index=2332), 15, 7)
# ('6qzp', Nucleotide(id='L5.G.2868.', base='G', chain_id='L5', index=2325), 15, 0)
# ('6qzp', Nucleotide(id='L5.A.2882.', base='A', chain_id='L5', index=2339), 15, 14)
# ('6qzp', Nucleotide(id='L5.A.2879.', base='A', chain_id='L5', index=2336), 15, 11)
# ('6qzp', Nucleotide(id='L5.U.2874.', base='U', chain_id='L5', index=2331), 15, 6)
#
# 4 2
# ('6qzp', Nucleotide(id='L5.A.3726.', base='A', chain_id='L5', index=2510), 6, 2)
# ('6qzp', Nucleotide(id='L5.G.3725.', base='G', chain_id='L5', index=2509), 6, 1)
# ('6qzp', Nucleotide(id='L5.A.3727.', base='A', chain_id='L5', index=2511), 6, 3)
# ('6qzp', Nucleotide(id='L5.PSU.3729.', base='PSU', chain_id='L5', index=2513), 6, 5)
# ('6qzp', Nucleotide(id='L5.A.3724.', base='A', chain_id='L5', index=2508), 6, 0)
# ('6qzp', Nucleotide(id='L5.A.3728.', base='A', chain_id='L5', index=2512), 6, 4)
#
# 4 2
# ('6qzp', Nucleotide(id='L5.B8H.3762.', base='B8H', chain_id='L5', index=2546), 9, 4)
# ('6qzp', Nucleotide(id='L5.C.3761.', base='C', chain_id='L5', index=2545), 9, 3)
# ('6qzp', Nucleotide(id='L5.A.3759.', base='A', chain_id='L5', index=2543), 9, 1)
# ('6qzp', Nucleotide(id='L5.A.3763.', base='A', chain_id='L5', index=2547), 9, 5)
# ('6qzp', Nucleotide(id='L5.PSU.3764.', base='PSU', chain_id='L5', index=2548), 9, 6)
# ('6qzp', Nucleotide(id='L5.A.3766.', base='A', chain_id='L5', index=2550), 9, 8)
# ('6qzp', Nucleotide(id='L5.A.3760.', base='A', chain_id='L5', index=2544), 9, 2)
# ('6qzp', Nucleotide(id='L5.G.3765.', base='G', chain_id='L5', index=2549), 9, 7)
# ('6qzp', Nucleotide(id='L5.U.3758.', base='U', chain_id='L5', index=2542), 9, 0)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.G.4019.', base='G', chain_id='L5', index=2803), 122, 73)
# ('6qzp', Nucleotide(id='L5.G.3970.', base='G', chain_id='L5', index=2754), 122, 24)
# ('6qzp', Nucleotide(id='L5.C.3976.', base='C', chain_id='L5', index=2760), 122, 30)
# ('6qzp', Nucleotide(id='L5.U.3968.', base='U', chain_id='L5', index=2752), 122, 22)
# ('6qzp', Nucleotide(id='L5.C.4037.', base='C', chain_id='L5', index=2821), 122, 91)
# ('6qzp', Nucleotide(id='L5.A.3947.', base='A', chain_id='L5', index=2731), 122, 1)
# ('6qzp', Nucleotide(id='L5.C.3978.', base='C', chain_id='L5', index=2762), 122, 32)
# ('6qzp', Nucleotide(id='L5.C.4051.', base='C', chain_id='L5', index=2835), 122, 105)
# ('6qzp', Nucleotide(id='L5.G.3967.', base='G', chain_id='L5', index=2751), 122, 21)
# ('6qzp', Nucleotide(id='L5.G.4027.', base='G', chain_id='L5', index=2811), 122, 81)
# ('6qzp', Nucleotide(id='L5.C.4021.', base='C', chain_id='L5', index=2805), 122, 75)
# ('6qzp', Nucleotide(id='L5.A.4048.', base='A', chain_id='L5', index=2832), 122, 102)
# ('6qzp', Nucleotide(id='L5.G.3951.', base='G', chain_id='L5', index=2735), 122, 5)
# ('6qzp', Nucleotide(id='L5.U.3957.', base='U', chain_id='L5', index=2741), 122, 11)
# ('6qzp', Nucleotide(id='L5.C.4059.', base='C', chain_id='L5', index=2843), 122, 113)
# ('6qzp', Nucleotide(id='L5.C.3977.', base='C', chain_id='L5', index=2761), 122, 31)
# ('6qzp', Nucleotide(id='L5.C.3982.', base='C', chain_id='L5', index=2766), 122, 36)
# ('6qzp', Nucleotide(id='L5.C.3988.', base='C', chain_id='L5', index=2772), 122, 42)
# ('6qzp', Nucleotide(id='L5.G.3958.', base='G', chain_id='L5', index=2742), 122, 12)
# ('6qzp', Nucleotide(id='L5.U.4020.', base='U', chain_id='L5', index=2804), 122, 74)
# ('6qzp', Nucleotide(id='L5.G.4045.', base='G', chain_id='L5', index=2829), 122, 99)
# ('6qzp', Nucleotide(id='L5.G.3983.', base='G', chain_id='L5', index=2767), 122, 37)
# ('6qzp', Nucleotide(id='L5.A.3954.', base='A', chain_id='L5', index=2738), 122, 8)
# ('6qzp', Nucleotide(id='L5.U.4058.', base='U', chain_id='L5', index=2842), 122, 112)
# ('6qzp', Nucleotide(id='L5.A.4053.', base='A', chain_id='L5', index=2837), 122, 107)
# ('6qzp', Nucleotide(id='L5.A.4046.', base='A', chain_id='L5', index=2830), 122, 100)
# ('6qzp', Nucleotide(id='L5.C.3989.', base='C', chain_id='L5', index=2773), 122, 43)
# ('6qzp', Nucleotide(id='L5.A.3952.', base='A', chain_id='L5', index=2736), 122, 6)
# ('6qzp', Nucleotide(id='L5.A.4003.', base='A', chain_id='L5', index=2787), 122, 57)
# ('6qzp', Nucleotide(id='L5.A.4050.', base='A', chain_id='L5', index=2834), 122, 104)
# ('6qzp', Nucleotide(id='L5.C.4009.', base='C', chain_id='L5', index=2793), 122, 63)
# ('6qzp', Nucleotide(id='L5.U.3950.', base='U', chain_id='L5', index=2734), 122, 4)
# ('6qzp', Nucleotide(id='L5.G.4013.', base='G', chain_id='L5', index=2797), 122, 67)
# ('6qzp', Nucleotide(id='L5.U.4044.', base='U', chain_id='L5', index=2828), 122, 98)
# ('6qzp', Nucleotide(id='L5.C.3998.', base='C', chain_id='L5', index=2782), 122, 52)
# ('6qzp', Nucleotide(id='L5.G.4017.', base='G', chain_id='L5', index=2801), 122, 71)
# ('6qzp', Nucleotide(id='L5.G.3946.', base='G', chain_id='L5', index=2730), 122, 0)
# ('6qzp', Nucleotide(id='L5.G.4032.', base='G', chain_id='L5', index=2816), 122, 86)
# ('6qzp', Nucleotide(id='L5.C.3984.', base='C', chain_id='L5', index=2768), 122, 38)
# ('6qzp', Nucleotide(id='L5.C.3985.', base='C', chain_id='L5', index=2769), 122, 39)
# ('6qzp', Nucleotide(id='L5.G.3956.', base='G', chain_id='L5', index=2740), 122, 10)
# ('6qzp', Nucleotide(id='L5.A.4047.', base='A', chain_id='L5', index=2831), 122, 101)
# ('6qzp', Nucleotide(id='L5.U.4060.', base='U', chain_id='L5', index=2844), 122, 114)
# ('6qzp', Nucleotide(id='L5.U.4063.', base='U', chain_id='L5', index=2847), 122, 117)
# ('6qzp', Nucleotide(id='L5.A.3960.', base='A', chain_id='L5', index=2744), 122, 14)
# ('6qzp', Nucleotide(id='L5.U.3993.', base='U', chain_id='L5', index=2777), 122, 47)
# ('6qzp', Nucleotide(id='L5.G.3955.', base='G', chain_id='L5', index=2739), 122, 9)
# ('6qzp', Nucleotide(id='L5.C.4033.', base='C', chain_id='L5', index=2817), 122, 87)
# ('6qzp', Nucleotide(id='L5.G.4012.', base='G', chain_id='L5', index=2796), 122, 66)
# ('6qzp', Nucleotide(id='L5.G.4005.', base='G', chain_id='L5', index=2789), 122, 59)
# ('6qzp', Nucleotide(id='L5.C.3999.', base='C', chain_id='L5', index=2783), 122, 53)
# ('6qzp', Nucleotide(id='L5.A.3963.', base='A', chain_id='L5', index=2747), 122, 17)
# ('6qzp', Nucleotide(id='L5.C.4022.', base='C', chain_id='L5', index=2806), 122, 76)
# ('6qzp', Nucleotide(id='L5.G.3961.', base='G', chain_id='L5', index=2745), 122, 15)
# ('6qzp', Nucleotide(id='L5.U.4055.', base='U', chain_id='L5', index=2839), 122, 109)
# ('6qzp', Nucleotide(id='L5.G.4035.', base='G', chain_id='L5', index=2819), 122, 89)
# ('6qzp', Nucleotide(id='L5.U.3995.', base='U', chain_id='L5', index=2779), 122, 49)
# ('6qzp', Nucleotide(id='L5.G.4011.', base='G', chain_id='L5', index=2795), 122, 65)
# ('6qzp', Nucleotide(id='L5.U.3959.', base='U', chain_id='L5', index=2743), 122, 13)
# ('6qzp', Nucleotide(id='L5.A.3949.', base='A', chain_id='L5', index=2733), 122, 3)
# ('6qzp', Nucleotide(id='L5.G.4006.', base='G', chain_id='L5', index=2790), 122, 60)
# ('6qzp', Nucleotide(id='L5.C.3986.', base='C', chain_id='L5', index=2770), 122, 40)
# ('6qzp', Nucleotide(id='L5.G.4042.', base='G', chain_id='L5', index=2826), 122, 96)
# ('6qzp', Nucleotide(id='L5.G.4039.', base='G', chain_id='L5', index=2823), 122, 93)
# ('6qzp', Nucleotide(id='L5.U.3964.', base='U', chain_id='L5', index=2748), 122, 18)
# ('6qzp', Nucleotide(id='L5.G.3973.', base='G', chain_id='L5', index=2757), 122, 27)
# ('6qzp', Nucleotide(id='L5.C.4041.', base='C', chain_id='L5', index=2825), 122, 95)
# ('6qzp', Nucleotide(id='L5.C.3990.', base='C', chain_id='L5', index=2774), 122, 44)
# ('6qzp', Nucleotide(id='L5.A.3962.', base='A', chain_id='L5', index=2746), 122, 16)
# ('6qzp', Nucleotide(id='L5.G.4023.', base='G', chain_id='L5', index=2807), 122, 77)
# ('6qzp', Nucleotide(id='L5.G.4000.', base='G', chain_id='L5', index=2784), 122, 54)
# ('6qzp', Nucleotide(id='L5.G.4061.', base='G', chain_id='L5', index=2845), 122, 115)
# ('6qzp', Nucleotide(id='L5.C.4028.', base='C', chain_id='L5', index=2812), 122, 82)
# ('6qzp', Nucleotide(id='L5.G.4036.', base='G', chain_id='L5', index=2820), 122, 90)
# ('6qzp', Nucleotide(id='L5.U.4031.', base='U', chain_id='L5', index=2815), 122, 85)
# ('6qzp', Nucleotide(id='L5.U.4067.', base='U', chain_id='L5', index=2851), 122, 121)
# ('6qzp', Nucleotide(id='L5.C.4025.', base='C', chain_id='L5', index=2809), 122, 79)
# ('6qzp', Nucleotide(id='L5.C.4010.', base='C', chain_id='L5', index=2794), 122, 64)
# ('6qzp', Nucleotide(id='L5.G.4026.', base='G', chain_id='L5', index=2810), 122, 80)
# ('6qzp', Nucleotide(id='L5.C.4052.', base='C', chain_id='L5', index=2836), 122, 106)
# ('6qzp', Nucleotide(id='L5.C.4054.', base='C', chain_id='L5', index=2838), 122, 108)
# ('6qzp', Nucleotide(id='L5.G.3974.', base='G', chain_id='L5', index=2758), 122, 28)
# ('6qzp', Nucleotide(id='L5.G.4043.', base='G', chain_id='L5', index=2827), 122, 97)
# ('6qzp', Nucleotide(id='L5.G.4034.', base='G', chain_id='L5', index=2818), 122, 88)
# ('6qzp', Nucleotide(id='L5.G.4007.', base='G', chain_id='L5', index=2791), 122, 61)
# ('6qzp', Nucleotide(id='L5.G.3980.', base='G', chain_id='L5', index=2764), 122, 34)
# ('6qzp', Nucleotide(id='L5.G.4018.', base='G', chain_id='L5', index=2802), 122, 72)
# ('6qzp', Nucleotide(id='L5.C.4064.', base='C', chain_id='L5', index=2848), 122, 118)
# ('6qzp', Nucleotide(id='L5.G.4016.', base='G', chain_id='L5', index=2800), 122, 70)
# ('6qzp', Nucleotide(id='L5.G.4014.', base='G', chain_id='L5', index=2798), 122, 68)
# ('6qzp', Nucleotide(id='L5.G.3981.', base='G', chain_id='L5', index=2765), 122, 35)
# ('6qzp', Nucleotide(id='L5.A.3966.', base='A', chain_id='L5', index=2750), 122, 20)
# ('6qzp', Nucleotide(id='L5.C.4015.', base='C', chain_id='L5', index=2799), 122, 69)
# ('6qzp', Nucleotide(id='L5.G.3971.', base='G', chain_id='L5', index=2755), 122, 25)
# ('6qzp', Nucleotide(id='L5.C.3975.', base='C', chain_id='L5', index=2759), 122, 29)
# ('6qzp', Nucleotide(id='L5.U.4049.', base='U', chain_id='L5', index=2833), 122, 103)
# ('6qzp', Nucleotide(id='L5.G.3991.', base='G', chain_id='L5', index=2775), 122, 45)
# ('6qzp', Nucleotide(id='L5.G.4004.', base='G', chain_id='L5', index=2788), 122, 58)
# ('6qzp', Nucleotide(id='L5.C.3996.', base='C', chain_id='L5', index=2780), 122, 50)
# ('6qzp', Nucleotide(id='L5.C.4040.', base='C', chain_id='L5', index=2824), 122, 94)
# ('6qzp', Nucleotide(id='L5.C.4038.', base='C', chain_id='L5', index=2822), 122, 92)
# ('6qzp', Nucleotide(id='L5.C.4029.', base='C', chain_id='L5', index=2813), 122, 83)
# ('6qzp', Nucleotide(id='L5.A.4056.', base='A', chain_id='L5', index=2840), 122, 110)
# ('6qzp', Nucleotide(id='L5.G.3992.', base='G', chain_id='L5', index=2776), 122, 46)
# ('6qzp', Nucleotide(id='L5.G.3969.', base='G', chain_id='L5', index=2753), 122, 23)
# ('6qzp', Nucleotide(id='L5.C.3979.', base='C', chain_id='L5', index=2763), 122, 33)
# ('6qzp', Nucleotide(id='L5.C.3997.', base='C', chain_id='L5', index=2781), 122, 51)
# ('6qzp', Nucleotide(id='L5.A.3965.', base='A', chain_id='L5', index=2749), 122, 19)
# ('6qzp', Nucleotide(id='L5.G.3953.', base='G', chain_id='L5', index=2737), 122, 7)
# ('6qzp', Nucleotide(id='L5.C.3948.', base='C', chain_id='L5', index=2732), 122, 2)
# ('6qzp', Nucleotide(id='L5.G.3994.', base='G', chain_id='L5', index=2778), 122, 48)
# ('6qzp', Nucleotide(id='L5.G.4002.', base='G', chain_id='L5', index=2786), 122, 56)
# ('6qzp', Nucleotide(id='L5.C.4057.', base='C', chain_id='L5', index=2841), 122, 111)
# ('6qzp', Nucleotide(id='L5.C.4008.', base='C', chain_id='L5', index=2792), 122, 62)
# ('6qzp', Nucleotide(id='L5.A.3972.', base='A', chain_id='L5', index=2756), 122, 26)
# ('6qzp', Nucleotide(id='L5.A.4062.', base='A', chain_id='L5', index=2846), 122, 116)
# ('6qzp', Nucleotide(id='L5.C.4030.', base='C', chain_id='L5', index=2814), 122, 84)
# ('6qzp', Nucleotide(id='L5.C.4024.', base='C', chain_id='L5', index=2808), 122, 78)
# ('6qzp', Nucleotide(id='L5.U.4066.', base='U', chain_id='L5', index=2850), 122, 120)
# ('6qzp', Nucleotide(id='L5.C.3987.', base='C', chain_id='L5', index=2771), 122, 41)
# ('6qzp', Nucleotide(id='L5.C.4001.', base='C', chain_id='L5', index=2785), 122, 55)
# ('6qzp', Nucleotide(id='L5.G.4065.', base='G', chain_id='L5', index=2849), 122, 119)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.G.4254.', base='G', chain_id='L5', index=3038), 7, 3)
# ('6qzp', Nucleotide(id='L5.C.4252.', base='C', chain_id='L5', index=3036), 7, 1)
# ('6qzp', Nucleotide(id='L5.A.4256.', base='A', chain_id='L5', index=3040), 7, 5)
# ('6qzp', Nucleotide(id='L5.A.4257.', base='A', chain_id='L5', index=3041), 7, 6)
# ('6qzp', Nucleotide(id='L5.A.4253.', base='A', chain_id='L5', index=3037), 7, 2)
# ('6qzp', Nucleotide(id='L5.A.4255.', base='A', chain_id='L5', index=3039), 7, 4)
# ('6qzp', Nucleotide(id='L5.A.4251.', base='A', chain_id='L5', index=3035), 7, 0)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.G.4322.', base='G', chain_id='L5', index=3106), 4, 0)
# ('6qzp', Nucleotide(id='L5.A.4323.', base='A', chain_id='L5', index=3107), 4, 1)
# ('6qzp', Nucleotide(id='L5.A.4324.', base='A', chain_id='L5', index=3108), 4, 2)
# ('6qzp', Nucleotide(id='L5.A.4325.', base='A', chain_id='L5', index=3109), 4, 3)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.U.4419.', base='U', chain_id='L5', index=3203), 7, 1)
# ('6qzp', Nucleotide(id='L5.U.4420.', base='U', chain_id='L5', index=3204), 7, 2)
# ('6qzp', Nucleotide(id='L5.A.4422.', base='A', chain_id='L5', index=3206), 7, 4)
# ('6qzp', Nucleotide(id='L5.U.4423.', base='U', chain_id='L5', index=3207), 7, 5)
# ('6qzp', Nucleotide(id='L5.A.4424.', base='A', chain_id='L5', index=3208), 7, 6)
# ('6qzp', Nucleotide(id='L5.G.4418.', base='G', chain_id='L5', index=3202), 7, 0)
# ('6qzp', Nucleotide(id='L5.C.4421.', base='C', chain_id='L5', index=3205), 7, 3)
#
# 2 2
# ('6qzp', Nucleotide(id='L5.G.4541.', base='G', chain_id='L5', index=3325), 4, 0)
# ('6qzp', Nucleotide(id='L5.G.4543.', base='G', chain_id='L5', index=3327), 4, 2)
# ('6qzp', Nucleotide(id='L5.U.4542.', base='U', chain_id='L5', index=3326), 4, 1)
# ('6qzp', Nucleotide(id='L5.A.4544.', base='A', chain_id='L5', index=3328), 4, 3)
#
# 14 4
# ('6qzp', Nucleotide(id='L5.C.4598.', base='C', chain_id='L5', index=3382), 17, 1)
# ('6qzp', Nucleotide(id='L5.G.4604.', base='G', chain_id='L5', index=3388), 17, 7)
# ('6qzp', Nucleotide(id='L5.A.4611.', base='A', chain_id='L5', index=3395), 17, 14)
# ('6qzp', Nucleotide(id='L5.G.4608.', base='G', chain_id='L5', index=3392), 17, 11)
# ('6qzp', Nucleotide(id='L5.A.4602.', base='A', chain_id='L5', index=3386), 17, 5)
# ('6qzp', Nucleotide(id='L5.G.4600.', base='G', chain_id='L5', index=3384), 17, 3)
# ('6qzp', Nucleotide(id='L5.C.4612.', base='C', chain_id='L5', index=3396), 17, 15)
# ('6qzp', Nucleotide(id='L5.C.4603.', base='C', chain_id='L5', index=3387), 17, 6)
# ('6qzp', Nucleotide(id='L5.A.4605.', base='A', chain_id='L5', index=3389), 17, 8)
# ('6qzp', Nucleotide(id='L5.G.4609.', base='G', chain_id='L5', index=3393), 17, 12)
# ('6qzp', Nucleotide(id='L5.U.4601.', base='U', chain_id='L5', index=3385), 17, 4)
# ('6qzp', Nucleotide(id='L5.UR3.4597.', base='UR3', chain_id='L5', index=3381), 17, 0)
# ('6qzp', Nucleotide(id='L5.A.4610.', base='A', chain_id='L5', index=3394), 17, 13)
# ('6qzp', Nucleotide(id='L5.A.4607.', base='A', chain_id='L5', index=3391), 17, 10)
# ('6qzp', Nucleotide(id='L5.C.4613.', base='C', chain_id='L5', index=3397), 17, 16)
# ('6qzp', Nucleotide(id='L5.G.4606.', base='G', chain_id='L5', index=3390), 17, 9)
# ('6qzp', Nucleotide(id='L5.A.4599.', base='A', chain_id='L5', index=3383), 17, 2)
#
# 11 2
# ('6qzp', Nucleotide(id='L5.A.4701.', base='A', chain_id='L5', index=3485), 13, 12)
# ('6qzp', Nucleotide(id='L5.C.4695.', base='C', chain_id='L5', index=3479), 13, 6)
# ('6qzp', Nucleotide(id='L5.G.4694.', base='G', chain_id='L5', index=3478), 13, 5)
# ('6qzp', Nucleotide(id='L5.U.4699.', base='U', chain_id='L5', index=3483), 13, 10)
# ('6qzp', Nucleotide(id='L5.U.4689.', base='U', chain_id='L5', index=3473), 13, 0)
# ('6qzp', Nucleotide(id='L5.C.4693.', base='C', chain_id='L5', index=3477), 13, 4)
# ('6qzp', Nucleotide(id='L5.G.4690.', base='G', chain_id='L5', index=3474), 13, 1)
# ('6qzp', Nucleotide(id='L5.C.4696.', base='C', chain_id='L5', index=3480), 13, 7)
# ('6qzp', Nucleotide(id='L5.U.4697.', base='U', chain_id='L5', index=3481), 13, 8)
# ('6qzp', Nucleotide(id='L5.A.4700.', base='A', chain_id='L5', index=3484), 13, 11)
# ('6qzp', Nucleotide(id='L5.C.4698.', base='C', chain_id='L5', index=3482), 13, 9)
# ('6qzp', Nucleotide(id='L5.A.4692.', base='A', chain_id='L5', index=3476), 13, 3)
# ('6qzp', Nucleotide(id='L5.A.4691.', base='A', chain_id='L5', index=3475), 13, 2)
#
# 2 2
# ('6qzp', Nucleotide(id='L7.G.89.', base='G', chain_id='L7', index=88), 4, 2)
# ('6qzp', Nucleotide(id='L7.G.87.', base='G', chain_id='L7', index=86), 4, 0)
# ('6qzp', Nucleotide(id='L7.A.90.', base='A', chain_id='L7', index=89), 4, 3)
# ('6qzp', Nucleotide(id='L7.A.88.', base='A', chain_id='L7', index=87), 4, 1)
#
# 4 2
# ('6qzp', Nucleotide(id='S2.G.70.', base='G', chain_id='S2', index=69), 10, 0)
# ('6qzp', Nucleotide(id='S2.C.78.', base='C', chain_id='S2', index=77), 10, 8)
# ('6qzp', Nucleotide(id='S2.G.74.', base='G', chain_id='S2', index=73), 10, 4)
# ('6qzp', Nucleotide(id='S2.G.75.', base='G', chain_id='S2', index=74), 10, 5)
# ('6qzp', Nucleotide(id='S2.C.72.', base='C', chain_id='S2', index=71), 10, 2)
# ('6qzp', Nucleotide(id='S2.U.76.', base='U', chain_id='S2', index=75), 10, 6)
# ('6qzp', Nucleotide(id='S2.A.79.', base='A', chain_id='S2', index=78), 10, 9)
# ('6qzp', Nucleotide(id='S2.A.77.', base='A', chain_id='S2', index=76), 10, 7)
# ('6qzp', Nucleotide(id='S2.G.71.', base='G', chain_id='S2', index=70), 10, 1)
# ('6qzp', Nucleotide(id='S2.C.73.', base='C', chain_id='S2', index=72), 10, 3)
#
# 14 4
# ('6qzp', Nucleotide(id='S2.G.203.', base='G', chain_id='S2', index=202), 22, 14)
# ('6qzp', Nucleotide(id='S2.C.196.', base='C', chain_id='S2', index=195), 22, 7)
# ('6qzp', Nucleotide(id='S2.U.197.', base='U', chain_id='S2', index=196), 22, 8)
# ('6qzp', Nucleotide(id='S2.C.201.', base='C', chain_id='S2', index=200), 22, 12)
# ('6qzp', Nucleotide(id='S2.A.209.', base='A', chain_id='S2', index=208), 22, 20)
# ('6qzp', Nucleotide(id='S2.C.193.', base='C', chain_id='S2', index=192), 22, 4)
# ('6qzp', Nucleotide(id='S2.G.205.', base='G', chain_id='S2', index=204), 22, 16)
# ('6qzp', Nucleotide(id='S2.U.210.', base='U', chain_id='S2', index=209), 22, 21)
# ('6qzp', Nucleotide(id='S2.G.190.', base='G', chain_id='S2', index=189), 22, 1)
# ('6qzp', Nucleotide(id='S2.G.204.', base='G', chain_id='S2', index=203), 22, 15)
# ('6qzp', Nucleotide(id='S2.U.189.', base='U', chain_id='S2', index=188), 22, 0)
# ('6qzp', Nucleotide(id='S2.G.202.', base='G', chain_id='S2', index=201), 22, 13)
# ('6qzp', Nucleotide(id='S2.C.194.', base='C', chain_id='S2', index=193), 22, 5)
# ('6qzp', Nucleotide(id='S2.U.198.', base='U', chain_id='S2', index=197), 22, 9)
# ('6qzp', Nucleotide(id='S2.G.206.', base='G', chain_id='S2', index=205), 22, 17)
# ('6qzp', Nucleotide(id='S2.G.208.', base='G', chain_id='S2', index=207), 22, 19)
# ('6qzp', Nucleotide(id='S2.G.200.', base='G', chain_id='S2', index=199), 22, 11)
# ('6qzp', Nucleotide(id='S2.C.199.', base='C', chain_id='S2', index=198), 22, 10)
# ('6qzp', Nucleotide(id='S2.C.195.', base='C', chain_id='S2', index=194), 22, 6)
# ('6qzp', Nucleotide(id='S2.G.207.', base='G', chain_id='S2', index=206), 22, 18)
# ('6qzp', Nucleotide(id='S2.A.191.', base='A', chain_id='S2', index=190), 22, 2)
# ('6qzp', Nucleotide(id='S2.C.192.', base='C', chain_id='S2', index=191), 22, 3)
#
# 18 4
# ('6qzp', Nucleotide(id='S2.A.903.', base='A', chain_id='S2', index=773), 31, 25)
# ('6qzp', Nucleotide(id='S2.G.895.', base='G', chain_id='S2', index=765), 31, 17)
# ('6qzp', Nucleotide(id='S2.U.892.', base='U', chain_id='S2', index=762), 31, 14)
# ('6qzp', Nucleotide(id='S2.U.887.', base='U', chain_id='S2', index=757), 31, 9)
# ('6qzp', Nucleotide(id='S2.C.905.', base='C', chain_id='S2', index=775), 31, 27)
# ('6qzp', Nucleotide(id='S2.G.894.', base='G', chain_id='S2', index=764), 31, 16)
# ('6qzp', Nucleotide(id='S2.G.902.', base='G', chain_id='S2', index=772), 31, 24)
# ('6qzp', Nucleotide(id='S2.U.906.', base='U', chain_id='S2', index=776), 31, 28)
# ('6qzp', Nucleotide(id='S2.U.888.', base='U', chain_id='S2', index=758), 31, 10)
# ('6qzp', Nucleotide(id='S2.G.891.', base='G', chain_id='S2', index=761), 31, 13)
# ('6qzp', Nucleotide(id='S2.C.879.', base='C', chain_id='S2', index=749), 31, 1)
# ('6qzp', Nucleotide(id='S2.G.881.', base='G', chain_id='S2', index=751), 31, 3)
# ('6qzp', Nucleotide(id='S2.A.904.', base='A', chain_id='S2', index=774), 31, 26)
# ('6qzp', Nucleotide(id='S2.A.908.', base='A', chain_id='S2', index=778), 31, 30)
# ('6qzp', Nucleotide(id='S2.U.898.', base='U', chain_id='S2', index=768), 31, 20)
# ('6qzp', Nucleotide(id='S2.G.907.', base='G', chain_id='S2', index=777), 31, 29)
# ('6qzp', Nucleotide(id='S2.U.897.', base='U', chain_id='S2', index=767), 31, 19)
# ('6qzp', Nucleotide(id='S2.C.884.', base='C', chain_id='S2', index=754), 31, 6)
# ('6qzp', Nucleotide(id='S2.U.885.', base='U', chain_id='S2', index=755), 31, 7)
# ('6qzp', Nucleotide(id='S2.A.886.', base='A', chain_id='S2', index=756), 31, 8)
# ('6qzp', Nucleotide(id='S2.U.896.', base='U', chain_id='S2', index=766), 31, 18)
# ('6qzp', Nucleotide(id='S2.C.900.', base='C', chain_id='S2', index=770), 31, 22)
# ('6qzp', Nucleotide(id='S2.U.889.', base='U', chain_id='S2', index=759), 31, 11)
# ('6qzp', Nucleotide(id='S2.G.878.', base='G', chain_id='S2', index=748), 31, 0)
# ('6qzp', Nucleotide(id='S2.G.901.', base='G', chain_id='S2', index=771), 31, 23)
# ('6qzp', Nucleotide(id='S2.U.883.', base='U', chain_id='S2', index=753), 31, 5)
# ('6qzp', Nucleotide(id='S2.U.899.', base='U', chain_id='S2', index=769), 31, 21)
# ('6qzp', Nucleotide(id='S2.U.890.', base='U', chain_id='S2', index=760), 31, 12)
# ('6qzp', Nucleotide(id='S2.U.882.', base='U', chain_id='S2', index=752), 31, 4)
# ('6qzp', Nucleotide(id='S2.G.880.', base='G', chain_id='S2', index=750), 31, 2)
# ('6qzp', Nucleotide(id='S2.U.893.', base='U', chain_id='S2', index=763), 31, 15)
#
# 4 2
# ('6qzp', Nucleotide(id='S2.A.962.', base='A', chain_id='S2', index=832), 8, 4)
# ('6qzp', Nucleotide(id='S2.G.961.', base='G', chain_id='S2', index=831), 8, 3)
# ('6qzp', Nucleotide(id='S2.U.960.', base='U', chain_id='S2', index=830), 8, 2)
# ('6qzp', Nucleotide(id='S2.U.965.', base='U', chain_id='S2', index=835), 8, 7)
# ('6qzp', Nucleotide(id='S2.A.963.', base='A', chain_id='S2', index=833), 8, 5)
# ('6qzp', Nucleotide(id='S2.A.964.', base='A', chain_id='S2', index=834), 8, 6)
# ('6qzp', Nucleotide(id='S2.G.959.', base='G', chain_id='S2', index=829), 8, 1)
# ('6qzp', Nucleotide(id='S2.G.958.', base='G', chain_id='S2', index=828), 8, 0)
#
# 2 2
# ('6qzp', Nucleotide(id='S2.G.995.', base='G', chain_id='S2', index=865), 4, 0)
# ('6qzp', Nucleotide(id='S2.A.997.', base='A', chain_id='S2', index=867), 4, 2)
# ('6qzp', Nucleotide(id='S2.A.996.', base='A', chain_id='S2', index=866), 4, 1)
# ('6qzp', Nucleotide(id='S2.A.998.', base='A', chain_id='S2', index=868), 4, 3)
#
# 2 2
# ('6qzp', Nucleotide(id='S2.A.1181.', base='A', chain_id='S2', index=1051), 4, 2)
# ('6qzp', Nucleotide(id='S2.C.1180.', base='C', chain_id='S2', index=1050), 4, 1)
# ('6qzp', Nucleotide(id='S2.A.1182.', base='A', chain_id='S2', index=1052), 4, 3)
# ('6qzp', Nucleotide(id='S2.G.1179.', base='G', chain_id='S2', index=1049), 4, 0)
#
# 2 2
# ('6qzp', Nucleotide(id='S2.G.1354.', base='G', chain_id='S2', index=1224), 4, 0)
# ('6qzp', Nucleotide(id='S2.G.1356.', base='G', chain_id='S2', index=1226), 4, 2)
# ('6qzp', Nucleotide(id='S2.C.1355.', base='C', chain_id='S2', index=1225), 4, 1)
# ('6qzp', Nucleotide(id='S2.A.1357.', base='A', chain_id='S2', index=1227), 4, 3)
#
# 2 2
# ('6qzp', Nucleotide(id='S2.U.1462.', base='U', chain_id='S2', index=1332), 5, 1)
# ('6qzp', Nucleotide(id='S2.U.1463.', base='U', chain_id='S2', index=1333), 5, 2)
# ('6qzp', Nucleotide(id='S2.G.1461.', base='G', chain_id='S2', index=1331), 5, 0)
# ('6qzp', Nucleotide(id='S2.A.1465.', base='A', chain_id='S2', index=1335), 5, 4)
# ('6qzp', Nucleotide(id='S2.C.1464.', base='C', chain_id='S2', index=1334), 5, 3)
#
# 2 2
# ('6qzp', Nucleotide(id='S2.G.1566.', base='G', chain_id='S2', index=1436), 4, 0)
# ('6qzp', Nucleotide(id='S2.A.1569.', base='A', chain_id='S2', index=1439), 4, 3)
# ('6qzp', Nucleotide(id='S2.C.1568.', base='C', chain_id='S2', index=1438), 4, 2)
# ('6qzp', Nucleotide(id='S2.G.1567.', base='G', chain_id='S2', index=1437), 4, 1)
#
# 2 2
# ('4enc', Nucleotide(id='A.A.31.', base='A', chain_id='A', index=30), 4, 2)
# ('4enc', Nucleotide(id='A.G.29.', base='G', chain_id='A', index=28), 4, 0)
# ('4enc', Nucleotide(id='A.A.30.', base='A', chain_id='A', index=29), 4, 1)
# ('4enc', Nucleotide(id='A.A.32.', base='A', chain_id='A', index=31), 4, 3)
#
# 2 2
# ('3npq', Nucleotide(id='A.G.21.', base='G', chain_id='A', index=20), 4, 0)
# ('3npq', Nucleotide(id='A.A.22.', base='A', chain_id='A', index=21), 4, 1)
# ('3npq', Nucleotide(id='A.G.23.', base='G', chain_id='A', index=22), 4, 2)
# ('3npq', Nucleotide(id='A.A.24.', base='A', chain_id='A', index=23), 4, 3)
#
# 2 2
# ('5u3g', Nucleotide(id='B.G.19.', base='G', chain_id='B', index=18), 4, 0)
# ('5u3g', Nucleotide(id='B.A.21.', base='A', chain_id='B', index=20), 4, 2)
# ('5u3g', Nucleotide(id='B.A.22.', base='A', chain_id='B', index=21), 4, 3)
# ('5u3g', Nucleotide(id='B.A.20.', base='A', chain_id='B', index=19), 4, 1)
#
# 2 2
# ('5u3g', Nucleotide(id='B.A.51.', base='A', chain_id='B', index=50), 4, 3)
# ('5u3g', Nucleotide(id='B.A.49.', base='A', chain_id='B', index=48), 4, 1)
# ('5u3g', Nucleotide(id='B.A.50.', base='A', chain_id='B', index=49), 4, 2)
# ('5u3g', Nucleotide(id='B.G.48.', base='G', chain_id='B', index=47), 4, 0)
#
# 2 2
# ('3e5c', Nucleotide(id='A.A.20.', base='A', chain_id='A', index=19), 4, 1)
# ('3e5c', Nucleotide(id='A.G.19.', base='G', chain_id='A', index=18), 4, 0)
# ('3e5c', Nucleotide(id='A.A.21.', base='A', chain_id='A', index=20), 4, 2)
# ('3e5c', Nucleotide(id='A.A.22.', base='A', chain_id='A', index=21), 4, 3)
#
# 2 2
# ('3e5c', Nucleotide(id='A.A.45.', base='A', chain_id='A', index=44), 4, 3)
# ('3e5c', Nucleotide(id='A.A.44.', base='A', chain_id='A', index=43), 4, 2)
# ('3e5c', Nucleotide(id='A.G.42.', base='G', chain_id='A', index=41), 4, 0)
# ('3e5c', Nucleotide(id='A.A.43.', base='A', chain_id='A', index=42), 4, 1)
#
# 2 2
# ('2z75', Nucleotide(id='B.C.115.', base='C', chain_id='B', index=94), 4, 1)
# ('2z75', Nucleotide(id='B.G.116.', base='G', chain_id='B', index=95), 4, 2)
# ('2z75', Nucleotide(id='B.A.117.', base='A', chain_id='B', index=96), 4, 3)
# ('2z75', Nucleotide(id='B.G.114.', base='G', chain_id='B', index=93), 4, 0)
#
# 2 2
# ('4lvw', Nucleotide(id='A.A.62.', base='A', chain_id='A', index=61), 4, 3)
# ('4lvw', Nucleotide(id='A.A.60.', base='A', chain_id='A', index=59), 4, 1)
# ('4lvw', Nucleotide(id='A.G.61.', base='G', chain_id='A', index=60), 4, 2)
# ('4lvw', Nucleotide(id='A.G.59.', base='G', chain_id='A', index=58), 4, 0)
#
# 2 2
# ('4frg', Nucleotide(id='B.A.49.', base='A', chain_id='B', index=48), 4, 2)
# ('4frg', Nucleotide(id='B.G.47.', base='G', chain_id='B', index=46), 4, 0)
# ('4frg', Nucleotide(id='B.A.50.', base='A', chain_id='B', index=49), 4, 3)
# ('4frg', Nucleotide(id='B.A.48.', base='A', chain_id='B', index=47), 4, 1)

# %%
len(ag_hc_pairs)
# Out:
# 198

# %%
sum([len(c & ag_hc_pairs) for c in components if 
     len(c) == 4 and len(c & noncanonical_pairs) == len(c & ag_hc_pairs)]) / len(ag_hc_pairs)
# Out:
# 0.5555555555555556

# %% [markdown]
# Итого 55% SM-AG-HC пар лежат в маленьких повторяющихся структурах, где кроме них ничего нет.

# %%
all_chains = assemble_chains(NRLIST_PATH, CIF_DIR, OUT_DIR, SEC_STRUCT_DIR)
# Out:
# 100%|██████████| 1074/1074 [00:47<00:00, 22.64it/s]

# %%
noncanonical_lw = {}

for c in all_chains:
    if (c.pdb_id, c.id) in nonredundant_chain_ids:
        for bp in c.noncanonical_bps:
            noncanonical_lw[c.pdb_id, make_pair(bp.nt_left, bp.nt_right)] = bp.type.lw

# %%
regex = re.compile('[ct][SWH]{2}')
symmetric_keys = {}

for key in set(noncanonical_lw.values()):
    if regex.match(key):
        bond = ''.join(sorted(key[1:]))
        symmetric_keys[key] = key[0] + bond

# %%
stats = []

for pair_data in get_data():
    meta = pair_data.meta
    
    noncanonical = meta.type == 'noncanonical_bps'
    nonredundant = (meta.pdb_id, meta.pair.nt_left.chain_id) in nonredundant_chain_ids
    bases = [meta.pair.nt_left.base, meta.pair.nt_right.base] 
    standard = all([b in 'AUGC' for b in bases])
    
    if all([noncanonical, nonredundant, standard]):
        lw = symmetric_keys.get(noncanonical_lw[meta.pdb_id, make_pair(meta.pair.nt_left, meta.pair.nt_right)])
        
        if lw is not None:
            stats.append((''.join(sorted(bases)), pair_data.features.relation, lw))
# Out:
# 100%|██████████| 30/30 [03:02<00:00,  6.10s/it]

# %%
table_data = defaultdict(Counter)

for base, relation, lw in stats:
    table_data[base, lw][relation] += 1
    table_data['total', lw][relation] += 1
    table_data[base, 'total'][relation] += 1
    table_data['total', 'total'][relation] += 1

# %%
all_bases = list({a[0] for a in stats}) + ['total']
all_lws = list({a[2] for a in stats}) + ['total']

table = pd.DataFrame(index=all_bases, columns=all_lws)
for key, cntr in table_data.items():
    num = sum(cntr.values())
    table.loc[key] = tuple([int(100 * cntr[k] / num) for k in ['SM', 'LC', 'LR']]) + (num,)

# %%
table
# Out:
#                     tSS                tSW             tHH              tHS  \
# AG      (7, 51, 40, 52)   (38, 40, 20, 54)  (60, 0, 40, 5)  (95, 1, 3, 250)
# CU                  NaN     (100, 0, 0, 1)             NaN   (50, 50, 0, 4)
# CG       (100, 0, 0, 1)    (40, 0, 60, 10)  (0, 100, 0, 1)   (50, 50, 0, 2)
# AU       (100, 0, 0, 1)     (100, 0, 0, 4)  (100, 0, 0, 2)   (77, 22, 0, 9)
# AA                  NaN    (33, 33, 33, 3)  (96, 3, 0, 30)   (86, 6, 6, 15)
# CC                  NaN                NaN             NaN   (100, 0, 0, 6)
# GG     (43, 12, 43, 16)     (66, 33, 0, 3)  (50, 50, 0, 2)  (86, 13, 0, 15)
# AC                  NaN   (28, 50, 21, 14)  (100, 0, 0, 2)   (88, 11, 0, 9)
# UU       (50, 0, 50, 2)     (0, 100, 0, 1)             NaN   (100, 0, 0, 2)
# GU       (100, 0, 0, 1)    (75, 25, 0, 16)             NaN   (100, 0, 0, 4)
# total  (20, 39, 39, 73)  (46, 33, 19, 106)  (88, 7, 4, 42)  (93, 4, 2, 316)
#
#                     cWW                cSW               cSS  \
# AG       (88, 2, 8, 45)   (45, 35, 18, 37)   (5, 47, 47, 17)
# CU      (100, 0, 0, 24)    (33, 33, 33, 3)               NaN
# CG     (87, 1, 10, 156)     (50, 50, 0, 8)  (13, 33, 53, 15)
# AU      (74, 0, 25, 35)    (11, 55, 33, 9)    (100, 0, 0, 2)
# AA      (77, 11, 11, 9)    (63, 36, 0, 11)               NaN
# CC      (88, 11, 0, 18)    (12, 75, 12, 8)               NaN
# GG       (83, 16, 0, 6)     (20, 80, 0, 5)    (0, 20, 80, 5)
# AC       (94, 0, 5, 36)    (12, 87, 0, 24)   (0, 60, 40, 10)
# UU       (96, 0, 3, 32)     (0, 100, 0, 1)               NaN
# GU       (92, 7, 0, 27)   (33, 41, 25, 12)    (0, 50, 50, 4)
# total   (88, 2, 8, 388)  (33, 54, 12, 118)   (9, 41, 49, 53)
#
#                     cHS              tWW              cHH              tHW  \
# AG      (42, 52, 5, 19)   (100, 0, 0, 1)   (71, 28, 0, 7)   (91, 0, 8, 12)
# CU       (22, 77, 0, 9)   (66, 0, 33, 3)   (50, 50, 0, 4)   (50, 50, 0, 6)
# CG       (60, 40, 0, 5)   (75, 0, 25, 8)   (0, 66, 33, 3)   (25, 75, 0, 4)
# AU     (53, 23, 23, 13)  (90, 0, 10, 20)   (100, 0, 0, 1)  (94, 0, 4, 121)
# AA       (100, 0, 0, 8)  (89, 0, 10, 19)   (100, 0, 0, 1)  (82, 3, 14, 28)
# CC       (33, 66, 0, 6)   (50, 50, 0, 2)              NaN   (100, 0, 0, 2)
# GG     (53, 33, 13, 15)   (100, 0, 0, 2)              NaN  (75, 20, 5, 20)
# AC      (39, 60, 0, 23)   (50, 0, 50, 6)              NaN  (79, 20, 0, 34)
# UU       (0, 50, 50, 2)   (83, 0, 16, 6)              NaN   (100, 0, 0, 6)
# GU      (89, 10, 0, 48)  (37, 25, 37, 8)   (100, 0, 0, 1)   (75, 0, 25, 8)
# total  (60, 34, 4, 148)  (77, 4, 18, 75)  (58, 35, 5, 17)  (86, 7, 5, 241)
#
#                      cHW               total
# AG       (80, 5, 15, 20)   (70, 16, 12, 519)
# CU        (0, 100, 0, 3)     (64, 31, 3, 57)
# CG       (81, 18, 0, 11)   (74, 10, 15, 224)
# AU      (51, 23, 25, 39)    (79, 7, 12, 256)
# AA        (100, 0, 0, 1)     (85, 7, 7, 125)
# CC                   NaN     (66, 30, 2, 42)
# GG      (44, 40, 14, 27)   (56, 27, 15, 116)
# AC       (50, 50, 0, 10)    (56, 36, 7, 168)
# UU        (0, 0, 100, 2)     (83, 5, 11, 54)
# GU        (85, 14, 0, 7)    (77, 15, 7, 136)
# total  (57, 26, 15, 120)  (71, 16, 11, 1697)
